# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn.metrics import confusion_matrix
import shutil
import numpy as np
# Out:
# C:\Users\victo\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
batch_size = 32
image_size = (224, 224)

# %%
#Código para leer las imágenes: Data set de entrenamiento
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
                'Ruta/Train_Val',     #Directorio donde se encuentran
                labels='inferred',                      #Para tomar cada subdirectorio como una clase diferente
                label_mode='int',                       #Las etiquetas son numeros enteros
                validation_split=0.1,                   #90% datos entrenamiento, 10% validación
                subset="training",                      #Asignamos que este data set es de entrenamiento
                seed=20220331,                          #Variable relacionada con la aleatoriedad
                image_size=image_size,                  #Tamaño de las imágenes
                batch_size=batch_size,                  #Tamaño de los lotes de entrenamiento
            )
# Out:
# Found 630 files belonging to 9 classes.
# Using 567 files for training.

# %%
#Código para leer las imágenes: Data set de validación
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
                'Ruta/Train_Val',
                labels='inferred',
                label_mode='int',
                validation_split=0.1,
                subset="validation",
                seed=20220331,
                image_size=image_size,
                batch_size=batch_size,
            )
# Out:
# Found 630 files belonging to 9 classes.
# Using 63 files for validation.

# %%
# Obtener un lote de datos de validación
for imagenes, etiquetas in train_ds.take(1):
    # Crear una nueva figura
    plt.figure(figsize=(10, 10))

    # Iterar sobre las primeras 25 imágenes y etiquetas en el lote
    for i in range(25):
        # Obtener la imagen y la etiqueta correspondiente
        imagen = imagenes[i]
        etiqueta = etiquetas[i]

        # Convertir la etiqueta a una cadena si es necesario
        etiqueta = str(etiqueta.numpy()) if isinstance(etiqueta, tf.Tensor) else str(etiqueta)

        # Añadir una subparcela a la figura
        plt.subplot(5, 5, i + 1)
        plt.imshow(imagen.numpy().astype("uint8"))  # Mostrar la imagen como una matriz numpy
        plt.title(etiqueta)                         # Mostrar la etiqueta como título
        plt.axis("off")                             # Desactivar ejes

    # Ajustar el diseño y mostrar la figura
    plt.tight_layout()
    plt.show()

# %%
#funciones de perdida
#categorical cross entropy
loss=tf.losses.SparseCategoricalCrossentropy() #num_classes = 9
"""
loss='mae' #num_classes = 1
loss='mse' #num_classes = 1
"""
# Out:
# "\nloss='mae' #num_classes = 1\nloss='mse' #num_classes = 1\n"

# %%
#Numero clases:
num_classes = 9

# %%
# Definición del modelo
model = tf.keras.Sequential([
    # Capa convolucional 1
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Capa convolucional 2
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Capa convolucional 3
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Capa convolucional 4
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    # Capa de aplanamiento para conectar con las capas densas
    tf.keras.layers.Flatten(),
    # Primera capa densa
    tf.keras.layers.Dense(512, activation='relu'),
    # Capa de salida
    tf.keras.layers.Dense(num_classes, activation='softmax')  # Num_classes es el número de clases de salida
])
# Out:
# C:\Users\victo\anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#optimizers
#Descenso del gradiente
#lr_schedule = 0.05
#optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
#Optimizador adam
optimizer ='adam'

# %%
# Directorio donde se guarda el modelo
copia_modelo = 'modelos/BACKUP_2.keras'

# %%
#compilar
model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])

# %%
#PARA OTRAS FUNCIONES (CALLBACKS)

# Para otros callbacks
# Guarda el último modelo con el mejor ajuste en val_ts
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    copia_modelo,
    monitor="val_loss",
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode="auto"
)
shutil.rmtree('Ruta/log.txt') 
os.makedirs('Ruta/log.txt')
# Guarda la información de cada época, residuos, etc.
csv_logger = tf.keras.callbacks.CSVLogger(
    'log.txt',
    append=True,
    separator=','
)

# %%
#TE PARA LAS EPOCAS SI NO MEJORA EN 10 EPOCAS, y TE REDUCE LA LR SI NO MEJORA EN 5
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# %%
#ENTRENAR MODELO:
data_trainining = (train_ds)
model.fit(
    data_trainining,
    validation_data=val_ds,
    shuffle=True,
    epochs=300,
    callbacks=[checkpoint,early_stopping, reduce_lr,csv_logger],
)
# Out:
# Epoch 1/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1721 - loss: 47.3808
# Epoch 1: val_loss improved from inf to 2.20123, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.1733 - loss: 46.0894 - val_accuracy: 0.0952 - val_loss: 2.2012 - learning_rate: 0.0010
# Epoch 2/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2317 - loss: 2.0338
# Epoch 2: val_loss improved from 2.20123 to 1.96668, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.2317 - loss: 2.0332 - val_accuracy: 0.3016 - val_loss: 1.9667 - learning_rate: 0.0010
# Epoch 3/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2076 - loss: 2.0313
# Epoch 3: val_loss improved from 1.96668 to 1.80937, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.2092 - loss: 2.0279 - val_accuracy: 0.2698 - val_loss: 1.8094 - learning_rate: 0.0010
# Epoch 4/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3147 - loss: 1.7559
# Epoch 4: val_loss improved from 1.80937 to 1.69684, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.3169 - loss: 1.7532 - val_accuracy: 0.3492 - val_loss: 1.6968 - learning_rate: 0.0010
# Epoch 5/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3180 - loss: 1.7944
# Epoch 5: val_loss improved from 1.69684 to 1.66188, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.3181 - loss: 1.7955 - val_accuracy: 0.3968 - val_loss: 1.6619 - learning_rate: 0.0010
# Epoch 6/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3655 - loss: 1.7414
# Epoch 6: val_loss improved from 1.66188 to 1.59853, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.3657 - loss: 1.7389 - val_accuracy: 0.4127 - val_loss: 1.5985 - learning_rate: 0.0010
# Epoch 7/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4821 - loss: 1.4121
# Epoch 7: val_loss improved from 1.59853 to 1.54904, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4817 - loss: 1.4131 - val_accuracy: 0.4127 - val_loss: 1.5490 - learning_rate: 0.0010
# Epoch 8/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6022 - loss: 1.2437
# Epoch 8: val_loss did not improve from 1.54904
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5997 - loss: 1.2451 - val_accuracy: 0.4127 - val_loss: 1.5998 - learning_rate: 0.0010
# Epoch 9/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6458 - loss: 1.0194
# Epoch 9: val_loss improved from 1.54904 to 1.43871, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6448 - loss: 1.0212 - val_accuracy: 0.4603 - val_loss: 1.4387 - learning_rate: 0.0010
# Epoch 10/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6049 - loss: 1.0076
# Epoch 10: val_loss did not improve from 1.43871
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6045 - loss: 1.0109 - val_accuracy: 0.4286 - val_loss: 1.4612 - learning_rate: 0.0010
# Epoch 11/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7218 - loss: 0.8192
# Epoch 11: val_loss improved from 1.43871 to 1.41763, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7203 - loss: 0.8213 - val_accuracy: 0.5079 - val_loss: 1.4176 - learning_rate: 0.0010
# Epoch 12/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7191 - loss: 0.6956
# Epoch 12: val_loss did not improve from 1.41763
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7189 - loss: 0.6968 - val_accuracy: 0.5238 - val_loss: 1.5626 - learning_rate: 0.0010
# Epoch 13/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7883 - loss: 0.5508
# Epoch 13: val_loss did not improve from 1.41763
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7886 - loss: 0.5516 - val_accuracy: 0.4286 - val_loss: 1.5523 - learning_rate: 0.0010
# Epoch 14/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8335 - loss: 0.4471
# Epoch 14: val_loss did not improve from 1.41763
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8326 - loss: 0.4493 - val_accuracy: 0.5397 - val_loss: 1.4893 - learning_rate: 0.0010
# Epoch 15/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8295 - loss: 0.4342
# Epoch 15: val_loss improved from 1.41763 to 1.41337, saving model to modelos/BACKUP_2.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.8286 - loss: 0.4369 - val_accuracy: 0.5397 - val_loss: 1.4134 - learning_rate: 0.0010
# Epoch 16/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8189 - loss: 0.4869
# Epoch 16: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8185 - loss: 0.4871 - val_accuracy: 0.4762 - val_loss: 1.7252 - learning_rate: 0.0010
# Epoch 17/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8176 - loss: 0.5110
# Epoch 17: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8179 - loss: 0.5096 - val_accuracy: 0.4762 - val_loss: 2.2145 - learning_rate: 0.0010
# Epoch 18/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8251 - loss: 0.5414
# Epoch 18: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8246 - loss: 0.5413 - val_accuracy: 0.5238 - val_loss: 1.5426 - learning_rate: 0.0010
# Epoch 19/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8572 - loss: 0.4052
# Epoch 19: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8575 - loss: 0.4039 - val_accuracy: 0.5397 - val_loss: 2.1894 - learning_rate: 0.0010
# Epoch 20/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8661 - loss: 0.3507
# Epoch 20: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8665 - loss: 0.3496 - val_accuracy: 0.5079 - val_loss: 1.7455 - learning_rate: 0.0010
# Epoch 21/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9366 - loss: 0.2045
# Epoch 21: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9366 - loss: 0.2045 - val_accuracy: 0.4921 - val_loss: 1.8308 - learning_rate: 1.0000e-04
# Epoch 22/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9488 - loss: 0.1651
# Epoch 22: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9485 - loss: 0.1648 - val_accuracy: 0.4762 - val_loss: 2.0025 - learning_rate: 1.0000e-04
# Epoch 23/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9615 - loss: 0.1372
# Epoch 23: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9616 - loss: 0.1373 - val_accuracy: 0.4921 - val_loss: 1.9790 - learning_rate: 1.0000e-04
# Epoch 24/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9651 - loss: 0.1230
# Epoch 24: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9650 - loss: 0.1234 - val_accuracy: 0.4921 - val_loss: 2.0618 - learning_rate: 1.0000e-04
# Epoch 25/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9712 - loss: 0.1210
# Epoch 25: val_loss did not improve from 1.41337
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9711 - loss: 0.1209 - val_accuracy: 0.4921 - val_loss: 2.0963 - learning_rate: 1.0000e-04

# %%
# Carga el modelo guardado
modelo = tf.keras.models.load_model(copia_modelo)
# Muestra un resumen del modelo
modelo.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     9,437,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         4,617 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,049,437 (110.81 MB)
#  Trainable params: 9,683,145 (36.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,366,292 (73.88 MB)

# %%
#Cargamos el data set Test:
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
                'C:/Users/victo/OneDrive/Fisica/Cuarto de carrera/TFG/Test',  # Directorio donde se encuentran los datos de prueba
                labels='inferred',                      # Para tomar cada subdirectorio como una clase diferente
                label_mode='int',                       # Las etiquetas son números enteros
                seed=20220331,                          # Variable relacionada con la aleatoriedad
                image_size=image_size,                  # Tamaño de las imágenes
                batch_size=batch_size,                  # Tamaño de los lotes de prueba
            )
# Out:
# Found 2565 files belonging to 9 classes.

# %%
# Evaluar el modelo en el conjunto de datos de prueba
test_loss, test_accuracy = model.evaluate(test_ds)

# Imprimir la precisión en el conjunto de datos de prueba
print("Precisión en el conjunto de datos de prueba:", test_accuracy)
# Out:
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 23s 287ms/step - accuracy: 0.8030 - loss: 0.8794
# Precisión en el conjunto de datos de prueba: 0.7922027111053467

# %%
# Obtener la matriz de confusión
true_labels = []
predicted_labels = []

for images, labels in test_ds:
    true_labels.extend(labels.numpy())
    predicted_labels.extend(np.argmax(model.predict(images), axis=-1))

conf_matrix = confusion_matrix(predicted_labels, true_labels)

# Calcular el porcentaje de imágenes en cada cuadrado de la matriz de confusión
total_per_class = np.sum(conf_matrix, axis=0)  # Total de imágenes por clase
conf_matrix_percentage = conf_matrix / total_per_class[np.newaxis, :] * 100

# Crear una matriz de strings con el número de imágenes y el porcentaje
conf_matrix_labels = np.empty(conf_matrix.shape, dtype=object)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        conf_matrix_labels[i, j] = f'{conf_matrix[i, j]}\n({conf_matrix_percentage[i, j]:.1f}%)'

# Visualizar la matriz de confusión con porcentajes y números de imágenes
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_percentage, annot=conf_matrix_labels, fmt='', cmap='coolwarm', cbar=False)
plt.xlabel('Etiqueta Real')
plt.ylabel('Etiqueta Predicha')
plt.savefig('Ruta/Matriz_densidad.jpg')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step

# %%
# Inicializar las listas para etiquetas verdaderas y predichas
true_labels = []
predicted_labels = []

# Iterar sobre el dataset de prueba para obtener las etiquetas y predicciones
for images, labels in test_ds:
    true_labels.extend(labels.numpy())  # Convertir las etiquetas a un array de numpy y añadirlas a true_labels
    predictions = model.predict(images)  # Obtener las predicciones del modelo
    predicted_labels.extend(np.argmax(predictions, axis=-1))  # Obtener el índice de la clase predicha y añadirlo a predicted_labels

# Convertir las listas a arrays de numpy
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Calcular las diferencias
differences = predicted_labels - true_labels

# Crear un histograma de las diferencias
plt.figure(figsize=(10, 6))
plt.hist(differences, bins=range(int(np.min(differences)), int(np.max(differences)) + 1), edgecolor='black', align='left')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('Ruta/histograma_diferencias.png')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
import scipy
#algunos valores estadísticos descriptivos
# Media (Promedio)
print(f"La media es: ",np.mean(differences))

# Mediana
print(f"La mediana es: {np.median(differences):.10f}")

# Moda
print(f"La moda es: {scipy.stats.mode(differences)[0][0]}")

# Varianza
print(f"La varianza es: ",np.var(differences))

# Desviación estándar
print(f"La desviación estandar es: ",np.std(differences))

# Rango
print(f"El rango es: ",np.std(differences))

#Asimetria:
print(f"La asimetría de la distribución es", scipy.stats.skew(differences))
# Out:
# La media es:  -0.016374269005847954
# La mediana es: 0.0000000000
# La moda es: 0
# La varianza es:  0.658601279026025
# La desviación estandar es:  0.8115425306328837
# El rango es:  0.8115425306328837
# La asimetría de la distribución es -0.7797556017782973

# %%
# Obtener las etiquetas únicas
unique_labels = np.unique(true_labels)

# Crear un subplot para cada etiqueta
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Iterar sobre cada etiqueta única
for i, label in enumerate(unique_labels):
    # Seleccionar solo las diferencias para la etiqueta actual
    label_differences = differences[true_labels == label]
    
    # Obtener el subplot correspondiente
    ax = axes[i // 3, i % 3]
    
    # Crear el histograma para la etiqueta actual
    ax.hist(label_differences, bins=range(int(np.min(differences)), int(np.max(differences)) + 1), edgecolor='black', align='left')
    ax.set_title(f'Octa {label}')
    ax.set_xlabel('Diferencia')
    ax.set_ylabel('Frecuencia')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Calcular la media, mediana y varianza
    mean = np.mean(label_differences)
    median = np.median(label_differences)
    variance = np.var(label_differences)
    
    # Agregar texto con la media, mediana y varianza al gráfico
    ax.text(0.05, 0.9, f'Media: {mean:.8f}\nMediana: {median:.8f}\nVarianza: {variance:.8f}', transform=ax.transAxes, fontsize=10, verticalalignment='top')

# Ajustar el espaciado entre subplots
plt.tight_layout()

# Guardar la figura
plt.savefig('Ruta/histogramas_por_octa.png')

# Mostrar los histogramas
plt.show()
